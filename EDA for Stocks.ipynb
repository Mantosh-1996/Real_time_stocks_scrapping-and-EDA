# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df_50 = pd.read_csv("Top_50_Stocks_India.csv", header=1)
df_main = pd.read_csv('All Stocks.csv')

# %%
df_main.head()
# Out:
#    Unnamed: 0           Name       LTP   %Chg     Volume Buy Price Sell Price  \
# 0           0    Adani Ports    750.30   2.07  4,585,484      0.00     750.30
# 1           1   Asian Paints  3,122.90   1.94    682,344      0.00   3,122.90
# 2           2      Axis Bank    736.05  -0.27  9,372,897      0.00     736.05
# 3           3     Bajaj Auto  3,635.05  -3.06    745,428  3,635.05       0.00
# 4           4  Bajaj Finance  7,579.10   1.70    497,128      0.00   7,579.10
#
#   Buy Qty Sell Qty      Open Prev.Close Unnamed: 11
# 0       0    3,055    737.70     735.10         NaN
# 1       0       30  3,089.00   3,063.50         NaN
# 2       0    1,026    742.80     738.05         NaN
# 3     129        0  3,782.00   3,749.95         NaN
# 4       0       11  7,500.00   7,452.70         NaN

# %%
df_50.head()
# Out:
#    0           Name       LTP  %Chg     Volume Buy Price Sell Price Buy Qty  \
# 0  1    Adani Ports    750.30  2.07  4,585,484      0.00     750.30       0
# 1  2   Asian Paints  3,122.90  1.94    682,344      0.00   3,122.90       0
# 2  3      Axis Bank    736.05 -0.27  9,372,897      0.00     736.05       0
# 3  4     Bajaj Auto  3,635.05 -3.06    745,428  3,635.05       0.00     129
# 4  5  Bajaj Finance  7,579.10  1.70    497,128      0.00   7,579.10       0
#
#   Sell Qty      Open Prev.Close
# 0    3,055    737.70     735.10
# 1       30  3,089.00   3,063.50
# 2    1,026    742.80     738.05
# 3        0  3,782.00   3,749.95
# 4       11  7,500.00   7,452.70

# %%
df_50.rename(columns={'0': 'Sl.No'},inplace=True)

# %%
df_main.rename(columns={'Unnamed: 0':'Sl.No',"Unnamed: 11" : "Temp"}, inplace=True)

# %%
df_main
# Out:
#      Sl.No           Name       LTP   %Chg      Volume Buy Price Sell Price  \
# 0        0    Adani Ports    750.30   2.07   4,585,484      0.00     750.30
# 1        1   Asian Paints  3,122.90   1.94     682,344      0.00   3,122.90
# 2        2      Axis Bank    736.05  -0.27   9,372,897      0.00     736.05
# 3        3     Bajaj Auto  3,635.05  -3.06     745,428  3,635.05       0.00
# 4        4  Bajaj Finance  7,579.10   1.70     497,128      0.00   7,579.10
# ..     ...            ...       ...    ...         ...       ...        ...
# 507    195         Voltas  1,264.35   1.24     569,624      0.00   1,264.35
# 508    196      Whirlpool  2,276.95  -1.73     254,066  2,276.95       0.00
# 509    197          Wipro    660.05   2.84   6,063,253    660.05       0.00
# 510    198       Yes Bank     13.15  -0.75  43,718,885     13.15       0.00
# 511    199  Zee Entertain    312.70  -0.43  13,094,002      0.00     312.70
#
#      Buy Qty Sell Qty      Open Prev.Close Temp
# 0          0    3,055    737.70     735.10  NaN
# 1          0       30  3,089.00   3,063.50  NaN
# 2          0    1,026    742.80     738.05  NaN
# 3        129        0  3,782.00   3,749.95  NaN
# 4          0       11  7,500.00   7,452.70  NaN
# ..       ...      ...       ...        ...  ...
# 507        0        1  1,255.50   1,248.90  NaN
# 508        9        0  2,330.00   2,317.05  NaN
# 509    4,123        0    648.00     641.80  NaN
# 510  308,853        0     13.30      13.25  NaN
# 511        0   17,817    322.50     314.05  NaN
#
# [512 rows x 12 columns]

# %% [markdown]
# ## Lets do some Feature engineering
# **Removing unnecesary columns**
#
#
# **changing data types of the continuous variables**
#
#
#
# **May be add some categorical columns to the dataframe for both the datas**

# %%
df_main= df_main[~df_main["Temp"].isnull()==False]
df_main.shape
# Out:
# (508, 12)

# %%
df_main.drop(columns=["Sl.No", "Temp"],inplace=True)

# %%
df_main.head()
# Out:
#             Name       LTP   %Chg     Volume Buy Price Sell Price Buy Qty  \
# 0    Adani Ports    750.30   2.07  4,585,484      0.00     750.30       0
# 1   Asian Paints  3,122.90   1.94    682,344      0.00   3,122.90       0
# 2      Axis Bank    736.05  -0.27  9,372,897      0.00     736.05       0
# 3     Bajaj Auto  3,635.05  -3.06    745,428  3,635.05       0.00     129
# 4  Bajaj Finance  7,579.10   1.70    497,128      0.00   7,579.10       0
#
#   Sell Qty      Open Prev.Close
# 0    3,055    737.70     735.10
# 1       30  3,089.00   3,063.50
# 2    1,026    742.80     738.05
# 3        0  3,782.00   3,749.95
# 4       11  7,500.00   7,452.70

# %%
df_main.drop_duplicates(inplace=True)

# %%
df_main.shape
# Out:
# (199, 10)

# %%
def x (l):
    for i in l:
        i.replace(',','')
    return l

# %%
df_main.iloc[:,1:]
# Out:
#           LTP   %Chg      Volume Buy Price Sell Price  Buy Qty Sell Qty  \
# 0      750.30   2.07   4,585,484      0.00     750.30        0    3,055
# 1    3,122.90   1.94     682,344      0.00   3,122.90        0       30
# 2      736.05  -0.27   9,372,897      0.00     736.05        0    1,026
# 3    3,635.05  -3.06     745,428  3,635.05       0.00      129        0
# 4    7,579.10   1.70     497,128      0.00   7,579.10        0       11
# ..        ...    ...         ...       ...        ...      ...      ...
# 304  2,791.35  -1.53     754,595      0.00   2,791.35        0       16
# 306  1,734.80   1.20     186,206      0.00   1,734.80        0      190
# 307    958.60   0.81   1,530,182      0.00     958.60        0       76
# 309    328.20   1.34  15,039,279    328.20       0.00    7,935        0
# 311     13.15  -0.75  43,718,885     13.15       0.00  308,853        0
#
#          Open Prev.Close
# 0      737.70     735.10
# 1    3,089.00   3,063.50
# 2      742.80     738.05
# 3    3,782.00   3,749.95
# 4    7,500.00   7,452.70
# ..        ...        ...
# 304  2,834.60   2,834.60
# 306  1,722.00   1,714.15
# 307    954.00     950.90
# 309    325.90     323.85
# 311     13.30      13.25
#
# [199 rows x 9 columns]

# %%
df_main.iloc[:,1:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 311
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LTP         199 non-null    object
#  1   %Chg        199 non-null    object
#  2   Volume      199 non-null    object
#  3   Buy Price   199 non-null    object
#  4   Sell Price  199 non-null    object
#  5   Buy Qty     199 non-null    object
#  6   Sell Qty    199 non-null    object
#  7   Open        199 non-null    object
#  8   Prev.Close  199 non-null    object
# dtypes: object(9)
# memory usage: 15.5+ KB

# %%
df_main["LTP"]= df_main["LTP"].apply(lambda x : float(x.replace(',','')))
df_main["%Chg"]= df_main["%Chg"].apply(lambda x : float(x.replace(',','')))
df_main["Volume"]= df_main["Volume"].apply(lambda x : float(x.replace(',','')))
df_main["Buy Price"]= df_main["Buy Price"].apply(lambda x : float(x.replace(',','')))
df_main["Sell Price"]= df_main["Sell Price"].apply(lambda x : float(x.replace(',','')))
df_main["Buy Qty"]= df_main["Buy Qty"].apply(lambda x : float(x.replace(',','')))
df_main["Sell Qty"]= df_main["Sell Qty"].apply(lambda x : float(x.replace(',','')))
df_main["Open"]= df_main["Open"].apply(lambda x : float(x.replace(',','')))
df_main["Prev.Close"]= df_main["Prev.Close"].apply(lambda x : float(x.replace(',','')))

# %%
df_main.iloc[:,1:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 311
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LTP         199 non-null    float64
#  1   %Chg        199 non-null    float64
#  2   Volume      199 non-null    float64
#  3   Buy Price   199 non-null    float64
#  4   Sell Price  199 non-null    float64
#  5   Buy Qty     199 non-null    float64
#  6   Sell Qty    199 non-null    float64
#  7   Open        199 non-null    float64
#  8   Prev.Close  199 non-null    float64
# dtypes: float64(9)
# memory usage: 15.5 KB

# %%
df_50.drop(columns=["Sl.No"], inplace=True)
df_50.iloc[:,1:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LTP         50 non-null     object
#  1   %Chg        50 non-null     float64
#  2   Volume      50 non-null     object
#  3   Buy Price   50 non-null     object
#  4   Sell Price  50 non-null     object
#  5   Buy Qty     50 non-null     object
#  6   Sell Qty    50 non-null     object
#  7   Open        50 non-null     object
#  8   Prev.Close  50 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 3.6+ KB

# %%
df_50["LTP"]= df_50["LTP"].apply(lambda x : float(x.replace(',','')))
df_50["Volume"]= df_50["Volume"].apply(lambda x : float(x.replace(',','')))
df_50["Buy Price"]= df_50["Buy Price"].apply(lambda x : float(x.replace(',','')))
df_50["Sell Price"]= df_50["Sell Price"].apply(lambda x : float(x.replace(',','')))
df_50["Buy Qty"]= df_50["Buy Qty"].apply(lambda x : float(x.replace(',','')))
df_50["Sell Qty"]= df_50["Sell Qty"].apply(lambda x : float(x.replace(',','')))
df_50["Open"]= df_50["Open"].apply(lambda x : float(x.replace(',','')))
df_50["Prev.Close"]= df_50["Prev.Close"].apply(lambda x : float(x.replace(',','')))
df_50.iloc[:,1:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LTP         50 non-null     float64
#  1   %Chg        50 non-null     float64
#  2   Volume      50 non-null     float64
#  3   Buy Price   50 non-null     float64
#  4   Sell Price  50 non-null     float64
#  5   Buy Qty     50 non-null     float64
#  6   Sell Qty    50 non-null     float64
#  7   Open        50 non-null     float64
#  8   Prev.Close  50 non-null     float64
# dtypes: float64(9)
# memory usage: 3.6 KB

# %%
df_main.head()

df_main["Status"]= df_main["%Chg"].apply(lambda x: "loss" if x<0 else "profit")
df_main.sort_values(["Volume"], ascending=False)
# Out:
#               Name       LTP  %Chg       Volume  Buy Price  Sell Price  \
# 158  Vodafone Idea     10.30  4.57  285024686.0       0.00       10.30
# 311       Yes Bank     13.15 -0.75   43718885.0      13.15        0.00
# 150     Tata Power    239.85  0.04   42038250.0     239.85        0.00
# 78            BHEL     65.15  0.54   36992832.0       0.00       65.15
# 59             PNB     41.75 -0.24   28798008.0      41.75        0.00
# ..             ...       ...   ...          ...        ...         ...
# 142   Sanofi India   8290.35  3.34      17339.0    8290.35        0.00
# 289        P and G  14867.30  1.52      16118.0       0.00    14867.30
# 135         Pfizer   5129.50 -0.21      13231.0       0.00     5129.50
# 279            MRF  78174.85  1.25      11688.0   78174.85        0.00
# 212   Abbott India  19754.65 -1.18      11666.0       0.00    19754.65
#
#       Buy Qty  Sell Qty      Open  Prev.Close  Status
# 158       0.0  390752.0      9.95        9.85  profit
# 311  308853.0       0.0     13.30       13.25    loss
# 150     497.0       0.0    242.00      239.75  profit
# 78        0.0   56549.0     65.00       64.80  profit
# 59     2376.0       0.0     42.20       41.85    loss
# ..        ...       ...       ...         ...     ...
# 142      56.0       0.0   8035.00     8022.35  profit
# 289       0.0       3.0  14754.85    14644.95  profit
# 135       0.0       7.0   5183.85     5140.30    loss
# 279       1.0       0.0  77580.00    77210.90  profit
# 212       0.0      69.0  20001.00    19990.45    loss
#
# [199 rows x 11 columns]

# %%
import sweetviz as swt

# %%
report= swt.compare(df_main[100:],df_main[:199] )
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
plt.figure(figsize=(20,15))
##Top loosers
loss= df_main[df_main["Status"]=="loss"]
loss.sort_values(["%Chg"], ascending=True, inplace=True)
d= sns.barplot(data = loss, x= "%Chg", y= "Name")
d.yaxis.tick_right()
plt.show()
