# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Final_Categorical_raw_data.csv",header=1)

# %%
df.head()
# Out:
#    0             Name       LTP      P/E Debt_to_equity     ESP    BVPS  \
# 0  1  Amara Raja Batt    665.55    22.55           0.01   37.87  246.49
# 1  2    Ashok Leyland    146.00  -106.07           0.53   -1.07   23.77
# 2  3       Bajaj Auto  3,583.80    21.86           0.00  167.90  942.51
# 3  4   Balkrishna Ind  2,322.15    27.72           0.17   60.91  310.39
# 4  5     Bharat Forge    802.75  -219.91           0.85   -2.71  116.98
#
#   Net_Profit(RS.cr) DSP(RS.)   NPM%   ROE% Category Unnamed: 12 Unnamed: 13  \
# 0            646.00    11.00   9.04  15.36    NIFTY        AUTO         NaN
# 1           -313.00     0.00  -2.05  -4.49    NIFTY        AUTO         NaN
# 2          4,550.00   140.00  16.40  17.80    NIFTY        AUTO         NaN
# 3          1,177.00    17.00  20.36  19.62    NIFTY        AUTO         NaN
# 4            -96.00     2.00  -1.53  -2.33    NIFTY        AUTO         NaN
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16
# ...

# %%
df.rename(columns={"0":"Sl_no"},inplace=True)

# %%
df1= df[~(df["Unnamed: 13"].isnull())]

# %%
df=df[df["Unnamed: 13"].isnull()]

# %%
df.shape
# Out:
# (255, 17)

# %%
df1.shape
# Out:
# (112, 17)

# %%
df1= df1[~(df1.Name=="Name LTP")]
df1.head()
# Out:
#     Sl_no            Name     LTP       P/E Debt_to_equity    ESP    BVPS  \
# 16     17         COFORGE    LTD.  5,839.35          39.19   0.00   74.68
# 27     28  Bank of Baroda   97.55     22.32           0.00   3.32  159.12
# 28     29   Bank of India   59.50     10.67           0.00   6.36  124.10
# 29     30     Bank of Mah   20.15     22.86           0.00   0.91   16.97
# 30     31     Canara Bank  220.05      7.96           0.00  19.11  328.68
#
#    Net_Profit(RS.cr) DSP(RS.)   NPM%  ROE% Category Unnamed: 12 Unnamed: 13  \
# 16            406.95   466.00  13.00  9.99    18.47       NIFTY          IT
# 27          1,454.00     0.00   1.95  1.87    NIFTY         PSU        BANK
# 28          2,199.00     0.00   5.38  5.12    NIFTY         PSU        BANK
# 29            551.00     0.00   4.64  5.13    NIFTY         PSU        BANK
# 30          2,702.00     0.00   3.84  5.34    NIFTY         PSU        BANK
#
#    Unnamed: 14 Unnamed: 15 Unnamed: 16
# ...

# %%
col= ["Sl_no", "Name" ,"LTP", "P/E", "Debt_to_equity", "ESP", "BVPS", "Net_Profit(RS.cr)" , "DSP(RS.)" , "NPM%", "ROE%", "Category", "unnames", "unnamed"]

# %%
d=df1.to_numpy()

# %%
for item in d:
    if item[2].isalpha():
        item[1]=item[1]+' '+item[2]
        del item[2]

# %%
d.shape
# Out:
# (93, 17)

# %%
d=d[:,:-3]

# %%
d.shape
# Out:
# (93, 14)

# %%
d
# Out:
# array([[17, 'COFORGE', 'LTD.', ..., '18.47', 'NIFTY', 'IT'],
#        [28, 'Bank of Baroda', '97.55', ..., 'NIFTY', 'PSU', 'BANK'],
#        [29, 'Bank of India', '59.50', ..., 'NIFTY', 'PSU', 'BANK'],
#        ...,
#        [328, 'V-Guard Ind', '251.50', ..., 'Nifty', 'Consr', 'Durbl'],
#        [329, 'Voltas', '1,235.45', ..., 'Nifty', 'Consr', 'Durbl'],
#        [330, 'Whirlpool', '2,311.75', ..., 'Nifty', 'Consr', 'Durbl']],
#       dtype=object)

# %%
for item in d:
    for i in range(len(item)):
        if item[i]=="NIFTY":
            item[i]= "_".join(item[i:])
        elif item[i]=="Nifty":
            item[i]= "_".join(item[i:])

# %%
d
# Out:
# array([[17, 'COFORGE', 'LTD.', ..., '18.47', 'NIFTY_IT', 'IT'],
#        [28, 'Bank of Baroda', '97.55', ..., 'NIFTY_PSU_BANK', 'PSU',
#         'BANK'],
#        [29, 'Bank of India', '59.50', ..., 'NIFTY_PSU_BANK', 'PSU',
#         'BANK'],
#        ...,
#        [328, 'V-Guard Ind', '251.50', ..., 'Nifty_Consr_Durbl', 'Consr',
#         'Durbl'],
#        [329, 'Voltas', '1,235.45', ..., 'Nifty_Consr_Durbl', 'Consr',
#         'Durbl'],
#        [330, 'Whirlpool', '2,311.75', ..., 'Nifty_Consr_Durbl', 'Consr',
#         'Durbl']], dtype=object)

# %%
l=pd.DataFrame(d, columns=col)

# %%
l
# Out:
#    Sl_no            Name        LTP       P/E Debt_to_equity     ESP  \
# 0     17         COFORGE       LTD.  5,839.35          39.19    0.00
# 1     28  Bank of Baroda      97.55     22.32           0.00    3.32
# 2     29   Bank of India      59.50     10.67           0.00    6.36
# 3     30     Bank of Mah      20.15     22.86           0.00    0.91
# 4     31     Canara Bank     220.05      7.96           0.00   19.11
# ..   ...             ...        ...       ...            ...     ...
# 88   326   Titan Company   2,499.35    142.16           0.58   10.96
# 89   327    TTK Prestige  11,006.50     41.37           0.03  175.23
# 90   328     V-Guard Ind     251.50     53.92           0.01    4.68
# 91   329          Voltas   1,235.45     63.13           0.05   15.87
# 92   330       Whirlpool   2,311.75     80.30           0.00   27.73
#
#         BVPS Net_Profit(RS.cr) DSP(RS.)   NPM%   ROE%           Category  \
# ...

# %%
l=l[~(l.LTP=='LTD.')]

# %%
l.unnames.value_counts()
# Out:
# SERV                 30
# FIN                  19
# Consr                15
# PSU                  12
# Pvt                  10
# 5.90                  2
# NIFTY_MEDIA           1
# -32.67                1
# Nifty_FinSrv25/50     1
# NIFTY_FIN             1
# Name: unnames, dtype: int64

# %%
l[l["unnames"]=="-32.67"]
# Out:
#   Sl_no    Name LTP   P/E Debt_to_equity    ESP  BVPS Net_Profit(RS.cr)  \
# 9    36  Punjab   &  Sind          17.25  -0.49  0.00            -35.71
#
#   DSP(RS.)       NPM%  ROE% Category unnames unnamed
# 9    20.64  -2,733.00  0.00   -39.18  -32.67   NIFTY

# %%
l[l["unnames"]=="5.90"]
# Out:
#    Sl_no  Name    LTP   P/E Debt_to_equity    ESP  BVPS Net_Profit(RS.cr)  \
# 34    85  TATA  Cons.  Prod         836.40  68.70  0.05              9.30
# 46   236  TATA  Cons.  Prod         836.40  68.70  0.05              9.30
#
#    DSP(RS.)    NPM%  ROE% Category unnames unnamed
# 34   169.33  993.00  4.05     8.56    5.90   NIFTY
# 46   169.33  993.00  4.05     8.56    5.90   NIFTY

# %%
l= l[~(l["unnames"]=="-32.67")]
l= l[~(l["unnames"]=="5.90")]

# %%
l.unnamed.value_counts()
# Out:
# SECTOR         30
# SERVICE        19
# Durbl          15
# BANK           12
# Bank           10
# FinSrv25/50     1
# MEDIA           1
# FIN             1
# Name: unnamed, dtype: int64

# %%
l.drop(columns=["unnames", "unnamed"])  

## This Data almost looks clean
# Out:
#    Sl_no            Name        LTP     P/E Debt_to_equity     ESP      BVPS  \
# 1     28  Bank of Baroda      97.55   22.32           0.00    3.32    159.12
# 2     29   Bank of India      59.50   10.67           0.00    6.36    124.10
# 3     30     Bank of Mah      20.15   22.86           0.00    0.91     16.97
# 4     31     Canara Bank     220.05    7.96           0.00   19.11    328.68
# 5     32    Central Bank      21.50   -9.42           0.00   -1.73     30.47
# ..   ...             ...        ...     ...            ...     ...       ...
# 88   326   Titan Company   2,499.35  142.16           0.58   10.96     84.29
# 89   327    TTK Prestige  11,006.50   41.37           0.03  175.23  1,084.31
# 90   328     V-Guard Ind     251.50   53.92           0.01    4.68     28.27
# 91   329          Voltas   1,235.45   63.13           0.05   15.87    152.04
# 92   330       Whirlpool   2,311.75   80.30           0.00   27.73    225.29
#
# ...

# %%
l.drop(columns=["unnames", "unnamed"],inplace=True)

# %%
l= l[~(l["Category"]=="15.84")]
l= l[~(l["Category"]=="-")]
l.Category.value_counts()
# Out:
# NIFTY_SERV_SECTOR    30
# NIFTY_FIN_SERVICE    19
# Nifty_Consr_Durbl    15
# NIFTY_PSU_BANK       12
# Nifty_Pvt_Bank       10
# Name: Category, dtype: int64

# %%
df.head()
# Out:
#    Sl_no             Name       LTP      P/E Debt_to_equity     ESP    BVPS  \
# 0      1  Amara Raja Batt    665.55    22.55           0.01   37.87  246.49
# 1      2    Ashok Leyland    146.00  -106.07           0.53   -1.07   23.77
# 2      3       Bajaj Auto  3,583.80    21.86           0.00  167.90  942.51
# 3      4   Balkrishna Ind  2,322.15    27.72           0.17   60.91  310.39
# 4      5     Bharat Forge    802.75  -219.91           0.85   -2.71  116.98
#
#   Net_Profit(RS.cr) DSP(RS.)   NPM%   ROE% Category Unnamed: 12 Unnamed: 13  \
# 0            646.00    11.00   9.04  15.36    NIFTY        AUTO         NaN
# 1           -313.00     0.00  -2.05  -4.49    NIFTY        AUTO         NaN
# 2          4,550.00   140.00  16.40  17.80    NIFTY        AUTO         NaN
# 3          1,177.00    17.00  20.36  19.62    NIFTY        AUTO         NaN
# 4            -96.00     2.00  -1.53  -2.33    NIFTY        AUTO         NaN
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16
# ...

# %%
df.drop(columns=["Unnamed: 13", "Unnamed: 14", "Unnamed: 15","Unnamed: 16"])
# Out:
#      Sl_no             Name       LTP      P/E Debt_to_equity     ESP  \
# 0        1  Amara Raja Batt    665.55    22.55           0.01   37.87
# 1        2    Ashok Leyland    146.00  -106.07           0.53   -1.07
# 2        3       Bajaj Auto  3,583.80    21.86           0.00  167.90
# 3        4   Balkrishna Ind  2,322.15    27.72           0.17   60.91
# 4        5     Bharat Forge    802.75  -219.91           0.85   -2.71
# ..     ...              ...       ...      ...            ...     ...
# 362    363    Mahanagar Gas    999.95    18.64           0.00   62.72
# 363    364             ONGC    157.40     7.91           0.50   12.92
# 364    365        Oil India    220.00     3.77           0.82   32.53
# 365    366     Petronet LNG    228.05    11.47           0.00   19.59
# 366    367         Reliance  2,464.00    26.23           0.32   76.37
#
#          BVPS Net_Profit(RS.cr) DSP(RS.)   NPM%   ROE% Category Unnamed: 12
# ...

# %%
df.drop(columns=["Unnamed: 13", "Unnamed: 14", "Unnamed: 15","Unnamed: 16"],inplace=True)

# %%
d=df.to_numpy()

# %%
d
# Out:
# array([[1, 'Amara Raja Batt', '665.55', ..., '15.36', 'NIFTY', 'AUTO'],
#        [2, 'Ashok Leyland', '146.00', ..., '-4.49', 'NIFTY', 'AUTO'],
#        [3, 'Bajaj Auto', '3,583.80', ..., '17.80', 'NIFTY', 'AUTO'],
#        ...,
#        [365, 'Oil India', '220.00', ..., '14.90', 'Nifty', 'OilGas'],
#        [366, 'Petronet LNG', '228.05', ..., '24.89', 'Nifty', 'OilGas'],
#        [367, 'Reliance', '2,464.00', ..., '7.01', 'Nifty', 'OilGas']],
#       dtype=object)

# %%
for item in d:
    for i in range(len(item)):
        if item[i]=="NIFTY":
            item[i]= "_".join(item[i:])
        elif item[i]=="Nifty":
            item[i]= "_".join(item[i:])

# %%
d
# Out:
# array([[1, 'Amara Raja Batt', '665.55', ..., '15.36', 'NIFTY_AUTO',
#         'AUTO'],
#        [2, 'Ashok Leyland', '146.00', ..., '-4.49', 'NIFTY_AUTO', 'AUTO'],
#        [3, 'Bajaj Auto', '3,583.80', ..., '17.80', 'NIFTY_AUTO', 'AUTO'],
#        ...,
#        [365, 'Oil India', '220.00', ..., '14.90', 'Nifty_OilGas',
#         'OilGas'],
#        [366, 'Petronet LNG', '228.05', ..., '24.89', 'Nifty_OilGas',
#         'OilGas'],
#        [367, 'Reliance', '2,464.00', ..., '7.01', 'Nifty_OilGas',
#         'OilGas']], dtype=object)

# %%
col= ["Sl_no", "Name" ,"LTP", "P/E", "Debt_to_equity", "ESP", "BVPS", "Net_Profit(RS.cr)" , "DSP(RS.)" , "NPM%", "ROE%", "Category", "unnames"]

# %%
x=pd.DataFrame(d, columns=col)

# %%
x.Category.value_counts()
df=x

# %%
df
# Out:
#     Sl_no             Name       LTP      P/E Debt_to_equity     ESP  \
# 0       1  Amara Raja Batt    665.55    22.55           0.01   37.87
# 1       2    Ashok Leyland    146.00  -106.07           0.53   -1.07
# 2       3       Bajaj Auto  3,583.80    21.86           0.00  167.90
# 3       4   Balkrishna Ind  2,322.15    27.72           0.17   60.91
# 4       5     Bharat Forge    802.75  -219.91           0.85   -2.71
# ..    ...              ...       ...      ...            ...     ...
# 250   363    Mahanagar Gas    999.95    18.64           0.00   62.72
# 251   364             ONGC    157.40     7.91           0.50   12.92
# 252   365        Oil India    220.00     3.77           0.82   32.53
# 253   366     Petronet LNG    228.05    11.47           0.00   19.59
# 254   367         Reliance  2,464.00    26.23           0.32   76.37
#
#          BVPS Net_Profit(RS.cr) DSP(RS.)   NPM%   ROE%      Category unnames
# ...

# %%
df.drop(columns=["unnames", "Sl_no"],inplace=True)

# %%
l.drop(columns=["Sl_no"],inplace=True)

# %%
col = l.columns

# %%
col=list(col)
col
# Out:
# ['Name',
#  'LTP',
#  'P/E',
#  'Debt_to_equity',
#  'ESP',
#  'BVPS',
#  'Net_Profit(RS.cr)',
#  'DSP(RS.)',
#  'NPM%',
#  'ROE%',
#  'Category']

# %%
Stock_Ind= pd.concat([df,l])

# %%
Stock_Ind
# Out:
#                Name        LTP      P/E Debt_to_equity     ESP      BVPS  \
# 0   Amara Raja Batt     665.55    22.55           0.01   37.87    246.49
# 1     Ashok Leyland     146.00  -106.07           0.53   -1.07     23.77
# 2        Bajaj Auto   3,583.80    21.86           0.00  167.90    942.51
# 3    Balkrishna Ind   2,322.15    27.72           0.17   60.91    310.39
# 4      Bharat Forge     802.75  -219.91           0.85   -2.71    116.98
# ..              ...        ...      ...            ...     ...       ...
# 88    Titan Company   2,499.35   142.16           0.58   10.96     84.29
# 89     TTK Prestige  11,006.50    41.37           0.03  175.23  1,084.31
# 90      V-Guard Ind     251.50    53.92           0.01    4.68     28.27
# 91           Voltas   1,235.45    63.13           0.05   15.87    152.04
# 92        Whirlpool   2,311.75    80.30           0.00   27.73    225.29
#
#    Net_Profit(RS.cr) DSP(RS.)   NPM%   ROE%           Category
# ...

# %%
Stock_Ind.LTP= Stock_Ind.LTP.apply(lambda x: x.replace(',',''))

# %%
Stock_Ind.Category.value_counts()
# Out:
# NIFTY_COMMODITIES    30
# NIFTY_SERV_SECTOR    30
# NIFTY_INFRA          30
# NIFTY_CONSUMPTION    29
# NIFTY_PSE            20
# Nifty_Healthcare     20
# Nifty_FinSrv25/50    19
# NIFTY_FIN_SERVICE    19
# Nifty_OilGas         15
# NIFTY_AUTO           15
# NIFTY_METAL          15
# Nifty_Consr_Durbl    15
# NIFTY_FMCG           14
# NIFTY_PSU_BANK       12
# NIFTY_REALTY         10
# NIFTY_ENERGY         10
# NIFTY_PHARMA         10
# Nifty_Pvt_Bank       10
# NIFTY_MEDIA           9
# NIFTY_IT              9
# Name: Category, dtype: int64

# %%
df=Stock_Ind

# %%
Stock_Ind=df

# %%
df.LTP= df.LTP.apply(lambda x: float(x.replace(',','')))

# %%
df.head()
# Out:
#               Name      LTP      P/E Debt_to_equity     ESP    BVPS  \
# 0  Amara Raja Batt   665.55    22.55           0.01   37.87  246.49
# 1    Ashok Leyland   146.00  -106.07           0.53   -1.07   23.77
# 2       Bajaj Auto  3583.80    21.86           0.00  167.90  942.51
# 3   Balkrishna Ind  2322.15    27.72           0.17   60.91  310.39
# 4     Bharat Forge   802.75  -219.91           0.85   -2.71  116.98
#
#   Net_Profit(RS.cr) DSP(RS.)   NPM%   ROE%    Category
# 0            646.00    11.00   9.04  15.36  NIFTY_AUTO
# 1           -313.00     0.00  -2.05  -4.49  NIFTY_AUTO
# 2          4,550.00   140.00  16.40  17.80  NIFTY_AUTO
# 3          1,177.00    17.00  20.36  19.62  NIFTY_AUTO
# 4            -96.00     2.00  -1.53  -2.33  NIFTY_AUTO

# %%
df= df[~(df.Debt_to_equity=='-')]

# %%
df.Debt_to_equity= df.Debt_to_equity.apply(lambda x: float(x.replace(',','')))
df.ESP= df.ESP.apply(lambda x: float(x.replace(',','')))
df.BVPS= df.BVPS.apply(lambda x: float(x.replace(',','')))
df["Net_Profit(RS.cr)"]= df["Net_Profit(RS.cr)"].apply(lambda x: float(x.replace(',','')))
df["NPM%"]	= df["NPM%"].apply(lambda x: float(x.replace(',','')))
df["DSP(RS.)"]= df["DSP(RS.)"].apply(lambda x: float(x.replace(',','')))
df["ROE%"] = df["ROE%"].apply(lambda x: float(x.replace(',','')))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 340 entries, 0 to 92
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               340 non-null    object
#  1   LTP                340 non-null    float64
#  2   P/E                340 non-null    object
#  3   Debt_to_equity     340 non-null    float64
#  4   ESP                340 non-null    float64
#  5   BVPS               340 non-null    float64
#  6   Net_Profit(RS.cr)  340 non-null    float64
#  7   DSP(RS.)           340 non-null    float64
#  8   NPM%               340 non-null    float64
#  9   ROE%               340 non-null    float64
#  10  Category           340 non-null    object
# dtypes: float64(8), object(3)
# memory usage: 31.9+ KB

# %%
df[df["P/E"]=="1,624.78"]
# Out:
#                 Name     LTP       P/E  Debt_to_equity   ESP  BVPS  \
# 82   Adani Green Ene  1313.5  1,624.78           27.22  0.68  5.03
# 124  Adani Green Ene  1313.5  1,624.78           27.22  0.68  5.03
# 47   Adani Green Ene  1313.5  1,624.78           27.22  0.68  5.03
#
#      Net_Profit(RS.cr)  DSP(RS.)  NPM%   ROE%           Category
# 82               176.0       0.0  5.63  24.39       NIFTY_ENERGY
# 124              176.0       0.0  5.63  24.39  NIFTY_COMMODITIES
# 47               176.0       0.0  5.63  24.39  NIFTY_SERV_SECTOR

# %%
df["P/E"] = df["P/E"].apply(lambda x: float(x.replace(',','')))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 340 entries, 0 to 92
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               340 non-null    object
#  1   LTP                340 non-null    float64
#  2   P/E                340 non-null    float64
#  3   Debt_to_equity     340 non-null    float64
#  4   ESP                340 non-null    float64
#  5   BVPS               340 non-null    float64
#  6   Net_Profit(RS.cr)  340 non-null    float64
#  7   DSP(RS.)           340 non-null    float64
#  8   NPM%               340 non-null    float64
#  9   ROE%               340 non-null    float64
#  10  Category           340 non-null    object
# dtypes: float64(9), object(2)
# memory usage: 31.9+ KB

# %%
df["Status"]= df["P/E"].apply(lambda x: "loss" if x<0 else "profit")

# %%
df.to_csv("Cleansed_categorical_data.csv")

# %%
import sweetviz as sweet

# %%
corr_matrix= df.iloc[:,1:10].corr()

# %%
corr_matrix
# Out:
#                         LTP       P/E  Debt_to_equity       ESP      BVPS  \
# LTP                1.000000  0.009314       -0.025970  0.915454  0.880798
# P/E                0.009314  1.000000        0.654578 -0.031093 -0.028434
# Debt_to_equity    -0.025970  0.654578        1.000000 -0.059354 -0.023535
# ESP                0.915454 -0.031093       -0.059354  1.000000  0.983358
# BVPS               0.880798 -0.028434       -0.023535  0.983358  1.000000
# Net_Profit(RS.cr) -0.067745 -0.073151       -0.052708 -0.001464 -0.007517
# DSP(RS.)           0.518150 -0.045369       -0.077947  0.394268  0.288113
# NPM%               0.017949  0.022850       -0.093544  0.051364 -0.003991
# ROE%               0.007345  0.028818       -0.519733  0.071097  0.015408
#
#                    Net_Profit(RS.cr)  DSP(RS.)      NPM%      ROE%
# LTP                        -0.067745  0.518150  0.017949  0.007345
# P/E                        -0.073151 -0.045369  0.022850  0.028818
# ...

# %%
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
